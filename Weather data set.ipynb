# %%
# Import the libraries
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# import the data set
weather=pd.read_csv("D:\\Downloads\\KAGGLE PROJECT\\Weather_Data.csv")

# %%
# load the file
weather
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
# check the the shape of file
weather.shape
# Out:
# (8784, 8)

# %%
print("Number of columns :",weather.shape[1])
print("Number of rows :",weather.shape[0])
# Out:
# Number of columns : 8
# Number of rows : 8784

# %%
# check the information
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
# check the columns name
weather.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
# type of file
type(weather)
# Out:
# pandas.core.frame.DataFrame

# %%
# first five record
weather.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
# last five records
weather.tail()
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# 8779            9.7     100.13    Snow
# 8780            9.7     100.03    Snow
# 8781            4.8      99.95    Snow
# 8782            9.7      99.91    Snow
# 8783           11.3      99.89    Snow

# %%
# check the missing value
weather.isna().sum()
# we dont have a missing value
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
weather.isna().count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
# Describe the data set
weather.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
# Value counts
weather.value_counts()
# Out:
# Date/Time        Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  Press_kPa  Weather
# 1/1/2012 0:00    -1.8    -3.9              86         4                8.0            101.24     Fog             1
# 6/1/2012 12:00    19.3    3.3              35         20               48.3           101.32     Cloudy          1
# 5/9/2012 7:00     14.3    12.5             89         15               4.8            100.12     Fog             1
# 5/9/2012 8:00     14.3    12.3             88         17               6.4            100.12     Fog             1
# 5/9/2012 9:00     14.0    12.3             89         9                4.0            100.10     Drizzle,Fog     1
#                                                                                                                 ..
# 12/8/2012 3:00    2.1    -1.5              77         6                25.0           101.18     Cloudy          1
# ...

# %%
weather.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
# import graph libraries
import matplotlib.pyplot as plt

# %%
# Rename the columns name
weather.rename(columns={"Rel Hum_%":"Humidity","Wind Speed_km/h":"Wind_Speed","Visibility_km":"Visibility"},inplace=True)

# %%
weather.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Humidity', 'Wind_Speed',
#        'Visibility', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
weather["Weather"].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
print(weather[weather["Wind_Speed"]=="clear"])
# Out:
# Empty DataFrame
# Columns: [Date/Time, Temp_C, Dew Point Temp_C, Humidity, Wind_Speed, Visibility, Press_kPa, Weather]
# Index: []

# %%
plt.figure(figsize=(8,3))
sns.histplot(weather["Humidity"],kde=True,color="red")
plt.show()

# %%
plt.figure(figsize=(8,3))
sns.histplot(weather["Wind_Speed"],kde=True,color="blue")
plt.show()

# %%
plt.figure(figsize=(8,3))
sns.countplot(data=weather,x="Wind_Speed")
plt.show()

# %%
plt.figure(figsize=(8,3))
sns.boxplot(weather["Humidity"],color="purple")
plt.show()
# Out:
# C:\Users\15-R\anaconda3.a\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(8,3))
sns.boxplot(weather["Wind_Speed"],color="green")
plt.show()
# Out:
# C:\Users\15-R\anaconda3.a\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=weather,x="Weather")
plt.xticks(rotation=90)
plt.show()

# %%
weather.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Humidity', 'Wind_Speed',
#        'Visibility', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
plt.scatter(x=weather['Temp_C'],y=weather['Visibility'])

# %%
plt.figure(figsize=(20,5))
weather["Wind_Speed"].plot.pie(autopct='%1.0f%%')
# pie chart does not work for this data set because this data is only depand the unique values.
# Out:
# <AxesSubplot:ylabel='Wind_Speed'>

# %%
sns.lineplot(x=weather.index,y=weather['Wind_Speed'])
# Out:
# <AxesSubplot:ylabel='Wind_Speed'>

# %%
sns.lineplot(x=weather.index,y=weather['Humidity'])
# Out:
# <AxesSubplot:ylabel='Humidity'>

# %%
# correlation
weather.corr()
# Out:
#                     Temp_C  Dew Point Temp_C  Humidity  Wind_Speed  \
# Temp_C            1.000000          0.932714 -0.220182   -0.061876
# Dew Point Temp_C  0.932714          1.000000  0.139494   -0.095685
# Humidity         -0.220182          0.139494  1.000000   -0.092743
# Wind_Speed       -0.061876         -0.095685 -0.092743    1.000000
# Visibility        0.273455          0.050813 -0.633683    0.004883
# Press_kPa        -0.236389         -0.320616 -0.231424   -0.356613
#
#                   Visibility  Press_kPa
# Temp_C              0.273455  -0.236389
# Dew Point Temp_C    0.050813  -0.320616
# Humidity           -0.633683  -0.231424
# Wind_Speed          0.004883  -0.356613
# Visibility          1.000000   0.231847
# Press_kPa           0.231847   1.000000

# %%
sns.heatmap(weather.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(weather)
